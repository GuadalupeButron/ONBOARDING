# %% [markdown]
# KATA 4
# EJERCICIO 1 TRANSFORMAR CADENAS

# %%
text = """Interesting facts about the Moon.\n The Moon is Earth's only satellite.\n There are several interesting facts about the Moon and how it affects life here on Earth.\n On average, the Moon moves 4cm away from the Earth every year.\n This yearly drift is not significant enough to cause immediate effects on Earth.\n The hig"""
text .split('\n')
# Out:
# ['Interesting facts about the Moon.',
#  " The Moon is Earth's only satellite.",
#  ' There are several interesting facts about the Moon and how it affects life here on Earth.',
#  ' On average, the Moon moves 4cm away from the Earth every year.',
#  ' This yearly drift is not significant enough to cause immediate effects on Earth.',
#  ' The hig']

# %%
text = """Interesting facts about the Moon.\n The Moon is Earth's only satellite.\n There are several interesting facts about the Moon and how it affects life here on Earth.\n On average, the Moon moves 4cm away from the Earth every year.\n This yearly drift is not significant enough to cause immediate effects on Earth.\n The hig"""
key_words = "average" "temperature" "distance"
key_words in text
# Out:
# False

# %%
text = """Interesting facts about the Moon.\n The Moon is Earth's only satellite.\n There are several interesting facts about the Moon and how it affects life here on Earth.\n On average, the Moon moves 4cm away from the Earth every year.\n This yearly drift is not significant enough to cause immediate effects on Earth.\n The hig"""
key_words = "average" "temperature" "distance"
for sentence in text:
    for key_word in key_words:
        if key_word in text:
            print(text)
        break
# Out:
# Interesting facts about the Moon.
#  The Moon is Earth's only satellite.
#  There are several interesting facts about the Moon and how it affects life here on Earth.
#  On average, the Moon moves 4cm away from the Earth every year.
#  This yearly drift is not significant enough to cause immediate effects on Earth.
#  The hig
# Interesting facts about the Moon.
#  The Moon is Earth's only satellite.
#  There are several interesting facts about the Moon and how it affects life here on Earth.
#  On average, the Moon moves 4cm away from the Earth every year.
#  This yearly drift is not significant enough to cause immediate effects on Earth.
#  The hig
# Interesting facts about the Moon.
#  The Moon is Earth's only satellite.
#  There are several interesting facts about the Moon and how it affects life here on Earth.
#  On average, the Moon moves 4cm away from the Earth every year.
#  This yearly drift is not significant enough to cause immediate effects on Earth.
#  The hig
# ...

# %%
text = """Interesting facts about the Moon.\n The Moon is Earth's only satellite.\n There are several interesting facts about the Moon and how it affects life here on Earth.\n On average, the Moon moves 4cm away from the Earth every year.\n This yearly drift is not significant enough to cause immediate effects on Earth.\n The hig"""
if "4cm".endswith("cm"):
    print("Esta medida es en centimentros")
# Out:
# Esta medida es en centimentros

# %% [markdown]
# EJERCICIO 2 FORMATEANDO CADENAS

# %%
name = "Moon"
gravity = 0.00162 # in kms
planet = "Earth"

title= f" Hablando de la gravedad de la {name} y {planet}"
print (title)
# Out:
#  Hablando de Moon y Earth

# %%
subject = 'Hablando de la gravedad de la Moon y de la Earth'
f'{subject.title()}'
# Out:
# 'Hablando De La Gravedad De La Moon Y De La Earth'

# %%
print(f" La gravedad que existe en la {name} respecto a {planet} deberia ser {gravity*1000})
# Out:
#   Input In [25]
#     print(f" La gravedad que existe en la {name} respecto a {planet} deberia ser {gravity*1000})
#           ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
Calculo = f""" {gravedad*80}
Nombre del planeta: {planeta}
Gravedad en {nombre}: {gravedad*1000}m/s"""
print (gravedad)
# Out:
# 0.00143

# %%
calculo = f""" {"-"*80}
Nombre del planeta: {planeta}
Gravedad en {nombre}: {gravedad*1000} m/s2
"""
print (calculo)
# Out:
#  --------------------------------------------------------------------------------
# Nombre del planeta: Pluton
# Gravedad en Diminuto: 1.4300000000000002 m/s2

# %%
calculo = f""" {"-"*80}
Nombre del planeta: {planeta}
Gravedad en {nombre}: {gravedad*1000} m/s2
"""
new_template = """
Datos de Gravedad sobre {nombre}
Nombre del planeta: {planeta}
Gravedad en {nombre}: {gravedad} m/s2
"""
print(new_template.format(nombre=nombre, planeta=planeta, gravedad=gravedad))
# Out:
# Datos de Gravedad sobre Ganímedes
# Nombre del planeta: Marte
# Gravedad en Ganímedes: 0.00143 m/s2
